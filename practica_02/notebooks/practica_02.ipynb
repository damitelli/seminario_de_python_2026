# %%
import sys
sys.path.append('../src')

# %%
import ej_01

# %%
ej_01.estadisticas_de_un_texto()
# Out:
# Total de lineas:  19
# Total de palabras:  137
# Promedio de palabras por línea:  7.21
# Líneas por encima del promedio (7.21 palabras):
#  - "    Special cases aren't special enough to break the rules." (9 palabras)
#  - "    In the face of ambiguity, refuse the temptation to guess." (10 palabras)
#  - "    There should be one-- and preferably only one --obvious way to do it." (13 palabras)
#  - "    Although that way may not be obvious at first unless you're Dutch." (12 palabras)
#  - "    Although never is often better than *right* now." (8 palabras)
#  - "    If the implementation is hard to explain, it's a bad idea." (11 palabras)
#  - "    If the implementation is easy to explain, it may be a good idea." (13 palabras)
#  - "    Namespaces are one honking great idea -- let's do more of those!" (12 palabras)

# %%
import ej_02

# %%
ej_02.duracion_de_una_playlist()
# Out:
# Duración total: 46m 53s
# Canción más larga: Stairway to Heaven (8:02)
# Canción más corta: Imagine (3:07)

# %%
import ej_03

# %%
ej_03.filtro_de_spoilers()
# Out:
# Ingrese las palabras spoiler (seperadas por coma):  marte
# La película sigue a un grupo de astronautas que viajan a ***** en una
# misión de rescate. El capitán Torres lidera al equipo a través de
# tormentas solares y fallos en el sistema de navegación. Al llegar a
# ***** descubren que la base está abandonada y los suministros
# destruidos. Torres decide sacrificar la nave nodriza para salvar al
# equipo y logran volver a la Tierra en una cápsula de emergencia. El
# final revela que Torres sobrevivió gracias a un pasaje secreto.

# %%
import ej_04

# %%
ej_04.validacion_de_email()
# Out:
# Ingrese un email:  a
# El email no es válido.

# %%
import ej_05

# %%
ej_05.calculadora_costo_de_envio()
# Out:
# Ingrese el peso del paquete (kg):  1
# Ingrese la zona del zona (local/regional/nacional): local
# Costo de envío: 1000

# %%
import ej_06

# %%
ej_06.analisis_de_hasthtag()
# Out:
# Hashtags trending (más de una aparición):
#    #Python: 3
#    #Programación: 3
#    #InteligenciaArtificial: 3
#    #Motivación: 2
#    #SerieAdicta: 2
#    #Tecnología: 2
# Total de hashtags únicos: 13

# %%
import ej_07

# %%
ej_07.sorteo_amigo_invisible()
# Out:
# Ingrese una lista de participantes separados por coma:  roberto
# Debe haber al menos tres participantes.
# Ingrese una lista de participantes separados por coma:  roberto,sofia,gabriel,agustin
#    Agustin --> Sofia
#    Sofia --> Roberto
#    Roberto --> Gabriel
#    Gabriel --> Agustin

# %%
import ej_08

# %%
ej_08.cifrado_cesar()
# Out:
# Ingrese un mensaje:  hola mundo
# Ingrese el desplazamiento:  3
# Mensaje cifrado: krod pxqgr
# Mensaje descifrado: hola mundo

# %%
import ej_09

# %%
ej_09.normalizacion_de_registro_de_alumnos()
# Out:
# Registros limpios de alumnos:
# Nombre               Nota  Estado
# ----------------------------------------
# Ana García           9     Aprobado
# Carlos Ruiz          6     Aprobado
# Gabriela Ríos        5     Aprobado
# Laura Méndez         8     Aprobado
# María Fernández      10    Aprobado
# Pedro López          4     Desaprobado
# Sofía Torres         9     Aprobado
#
# Total de alumnos válidos: 7

# %%
import ej_10

# %%
ej_10.simulación_de_competencia_de_cocina_y_ranking()
# Out:
# Ronda 1 - Entrada
# Ganador: Camila (26)
#
# Tabla de posiciones:
# Camila:      26
# Valentina:   24
# Lucía:       24
# Mateo:       22
# Santiago:    19
#
# Ronda 2 - Plato principal
# Ganador: Valentina (26)
#
# Tabla de posiciones:
# Valentina:   50
# Mateo:       46
# Camila:      46
# Lucía:       46
# Santiago:    44
#
# Ronda 3 - Postre
# Ganador: Lucía (27)
#
# Tabla de posiciones:
# Lucía:       73
# Valentina:   72
# Mateo:       72
# Camila:      70
# Santiago:    64
#
# Ronda 4 - Cocina internacional
# Ganador: Valentina (26)
#
# Tabla de posiciones:
# Valentina:   98
# Camila:      95
# Lucía:       95
# Mateo:       92
# Santiago:    88
#
# Ronda 5 - Final libre
# Ganador: Santiago (27)
#
# Tabla de posiciones:
# Valentina:   124
# Lucía:       118
# Mateo:       117
# Camila:      116
# Santiago:    115
#
# Tabla de posiciones final:
#
# Cocinero        Puntaje    Rondas ganadas    Mejor ronda    Promedio
#
# ...
